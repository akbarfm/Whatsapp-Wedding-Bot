# %%
import pywhatkit as kit
import pandas as pd
import time

# %%
# Lead contact list
contacts = pd.read_excel("DAPEG 15 OCT 2025.xlsx")

# %%
message = f"Hi there Jack, im here to inform you and also invite you to our wedding"

# %%
for i in range(0,5):
    kit.sendwhatmsg_instantly("+6287781400959",message, 10, False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 for i in range(0,5):
# ----> 2     kit.sendwhatmsg_instantly("+6287781400959",message, 10, False)
#
# File ~\AppData\Local\anaconda3\envs\etc\lib\site-packages\pywhatkit\whats.py:31, in sendwhatmsg_instantly(phone_no, message, wait_time, tab_close, close_time)
#      29 time.sleep(4)
#      30 pg.click(core.WIDTH / 2, core.HEIGHT / 2)
# ---> 31 time.sleep(wait_time - 4)
#      32 pg.press("enter")
#      33 log.log_message(_time=time.localtime(), receiver=phone_no, message=message)
#
# KeyboardInterrupt:

# %%
help(kit.sendwhatmsg_instantly)
# Out:
# Help on function sendwhatmsg_instantly in module pywhatkit.whats:
#
# sendwhatmsg_instantly(phone_no: str, message: str, wait_time: int = 15, tab_close: bool = False, close_time: int = 3) -> None
#     Send WhatsApp Message Instantly

# %%
kit.send
