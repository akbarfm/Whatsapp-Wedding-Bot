# %%
import pywhatkit as kit
import pandas as pd
import time

# %%
# Lead contact list
# df = pd.read_excel("TEST.xlsx")
df = pd.read_excel("DAPEG 15 OCT 2025.xlsx")

# %%
df = df.drop(df.index[-1])

# %%
df
# Out:
#     No                    Nama                    Name Panggilan  \
# 0    2    EVANDA CATUR SAPUTRA    Evanda Catur Saputra     Putra
# 1    3        SALSABILA ZAHRAH        Salsabila Zahrah     Salsa
# 2    4  MUHAMMAD RIFQI HANANDA  Muhammad Rifqi Hananda     Rifqi
# 3    5          MUSLIM TANJUNG          Muslim Tanjung   Tanjung
# 4    6       ISMAELIA ISKANDAR       Ismaelia Iskandar       Aji
# ..  ..                     ...                     ...       ...
# 92  94            ADILLA AULIA            Adilla Aulia       NaN
# 93  95            RANI SUSANTI            Rani Susanti       NaN
# 94  96            FAUZAN JAMAL            Fauzan Jamal       NaN
# 95  97     DIMAS ARYA DEWANGGA     Dimas Arya Dewangga       NaN
# 96  98            WENO MARIONA            Weno Mariona       NaN
#
#                    Column3  Gender Column2  Usia (tahun)  \
# 0     Evanda+Catur+Saputra    Male   Islam            25
# 1         Salsabila+Zahrah  Female   Islam            25
# ...

# %%
for index, col in df.iterrows():
    # print(f'{index+1}. {col["Name"]}')
    # print(f'Phone Number: {col["Phone"]}')
    # print(f'Message: \n{col["Message"]}\n
    
    # phone = col["Phone"]
    # if not phone.startswith("+"):
    #     phone = "+" + phone
    #     print(phone)
    kit.sendwhatmsg_instantly(col["Phone"],col["Message"],15, True, 2)
